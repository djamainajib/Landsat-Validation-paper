# %% [markdown]
# ### Setup Environment

# %%
import ee
ee.Authenticate()
ee.Initialize()

# %%
import LEAF
import SL2PV0 
import SL2PV1

# %% [markdown]
# ### Specify Sites to Process
# Sites correspond to readable Google Earth Engine Feature collections under which samples will be extracted. If the features have time stamps as properties the sampling interval can be restricted on a feature by feature basis. Otherwise the sampling interval must be specified the same for all features.

# %%
siteList=["projects/ee-modis250/assets/validationGBOV/NEON_2013-22_RMs_updated_parsed"]
# siteList = ["projects/ee-modis250/assets/validationCCRS/CCRSInSituLAI2019_HayRiverv3",\
#              "projects/ee-modis250/assets/validationCCRS/CCRSInSituLAI2019_Labradorv3",\
#              "projects/ee-modis250/assets/validationCCRS/CCRSInSituLAI2019_MerBleuv3",\
#              "projects/ee-modis250/assets/validationCCRS/CCRSInSituLAI2019_MtPolleyv3",\
#              "projects/ee-modis250/assets/validationCCRS/CCRSInSituLAI2019_PeaceRiverv3",\
#              "projects/ee-modis250/assets/validationCCRS/CCRSInSituLAI2019_TurkeyPointv3",\
#              "projects/ee-modis250/assets/validationCCRS/CCRSInSituLAI2019_VancouverIslandv3",\
#              "projects/ee-modis250/assets/validationCCRS/CCRSInSituLAI2019_Yellowknifev3",\
#              "projects/ee-modis250/assets/validationCCRS/CCRSInSituLAI2020_RingOfFirev3",\
#              "projects/ee-modis250/assets/validationCCRS/CCRSInSituLAI2021_NovaScotiav3"]

# %%
datapath='C:/Djamai_Najib/1_vegetation_parameters/1_scripts/LEAF-Landsat-Validation-paper/data/2_NEON2013_LC08/'

# %%
sensor='S2'
dict={'HLS':{'collection':'NASA/HLS/HLSL30/v002','scale':30,'buffer':45},'LC':{'collection':'LANDSAT/LC08/C02/T1_L2','scale':30,'buffer':45},'S2':{'collection':'COPERNICUS/S2_SR_HARMONIZED','scale':20,'buffer':30}}
dict[sensor]
# Out:
# {'collection': 'COPERNICUS/S2_SR_HARMONIZED', 'scale': 20, 'buffer': 30}

# %% [markdown]
# ### Run LEAF

# %%
# sitesDictionaryL08SR = LEAF.sampleSites(siteList, \
#                                                 imageCollectionName=dict[sensor]['collection'],\
#                                                 algorithm=SL2PV1, 
#                                                 variableName="LAI",\
#                                                 maxCloudcover=90,\
#                                                 outputScaleSize=dict[sensor]['scale'],\
#                                                 inputScaleSize=dict[sensor]['scale'],\
#                                                 bufferSpatialSize = dict[sensor]['buffer'],\
#                                                 bufferTemporalSize =[-7,7],  \
#                                                 subsamplingFraction = 0.99,\
#                                                 outputFileName=datapath,\
#                                                 feature_range=[0,200])

# %%
# sitesDictionaryL08SR = LEAF.sampleSites(siteList, \
#                                                 imageCollectionName=dict[sensor]['collection'],\
#                                                 algorithm=SL2PV1, 
#                                                 variableName="CWC",\
#                                                 maxCloudcover=90,\
#                                                 outputScaleSize=dict[sensor]['scale'],\
#                                                 inputScaleSize=dict[sensor]['scale'],\
#                                                 bufferSpatialSize = dict[sensor]['buffer'],\
#                                                 bufferTemporalSize =[-7,7],  \
#                                                 subsamplingFraction = 0.99,\
#                                                 outputFileName=datapath,\
#                                                 feature_range=[0,200])

# %%
# sitesDictionaryL08SR = LEAF.sampleSites(siteList, \
#                                                 imageCollectionName=dict[sensor]['collection'],\
#                                                 algorithm=SL2PV1, 
#                                                 variableName="CCC",\
#                                                 maxCloudcover=90,\
#                                                 outputScaleSize=dict[sensor]['scale'],\
#                                                 inputScaleSize=dict[sensor]['scale'],\
#                                                 bufferSpatialSize = dict[sensor]['buffer'],\
#                                                 bufferTemporalSize =[-7,7],  \
#                                                 subsamplingFraction = 0.99,\
#                                                 outputFileName=datapath,\
#                                                 feature_range=[0,200])

# %% [markdown]
# ###### Sample LAI from SL2P/LANDSAT-8 product

# %% [markdown]
# 1

# %%
sitesDictionaryL08SR = LEAF.sampleSites(siteList, \
                                                imageCollectionName=dict[sensor]['collection'],\
                                                algorithm=SL2PV1, 
                                                variableName="fCOVER",\
                                                maxCloudcover=90,\
                                                outputScaleSize=dict[sensor]['scale'],\
                                                inputScaleSize=dict[sensor]['scale'],\
                                                bufferSpatialSize = dict[sensor]['buffer'],\
                                                bufferTemporalSize =[-7,7],  \
                                                subsamplingFraction = 0.99,\
                                                outputFileName=datapath,\
                                                feature_range=[0,200])

# %%
sitesDictionaryL08SR = LEAF.sampleSites(siteList, \
                                                imageCollectionName=dict[sensor]['collection'],\
                                                algorithm=SL2PV1, 
                                                variableName="fAPAR",\
                                                maxCloudcover=90,\
                                                outputScaleSize=dict[sensor]['scale'],\
                                                inputScaleSize=dict[sensor]['scale'],\
                                                bufferSpatialSize = dict[sensor]['buffer'],\
                                                bufferTemporalSize =[-7,7],  \
                                                subsamplingFraction = 0.99,\
                                                outputFileName=datapath,\
                                                feature_range=[0,200])
# Out:
# STARTING LEAF IMAGE for  COPERNICUS/S2_SR_HARMONIZED
# Output path: C:/Djamai_Najib/1_vegetation_parameters/1_scripts/LEAF-Landsat-Validation-paper/data/2_NEON2013_LC08/NEON_2013-22_RMs_updated_parsed_COPERNICUS_S2_SR_HARMONIZED_fAPAR_0_200_SL2PV1_2024_04_19_18h_04mn.pkl
# Site:  projects/ee-modis250/assets/validationGBOV/NEON_2013-22_RMs_updated_parsed  with  14141  features.
# Data sampeling for features: from 0 to 200
# Feature n°: 0/200  -- startDate: 2022-09-02 02:00:00 -- endDate: 2022-09-16 02:00:00
# ----------------------------------------------------------------------------------------------------------
# 2022-09-02 02:00:00 2022-09-16 02:00:00
# Feature n°: 1/200  -- startDate: 2022-09-02 02:00:00 -- endDate: 2022-09-16 02:00:00
# ----------------------------------------------------------------------------------------------------------
# 2022-09-02 02:00:00 2022-09-16 02:00:00
# Feature n°: 2/200  -- startDate: 2022-09-02 02:00:00 -- endDate: 2022-09-16 02:00:00
# ...

# %%
1
# Out:
# 1

# %%
1
# Out:
# 1
